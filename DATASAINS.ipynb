# %% [markdown]
# <a href="https://colab.research.google.com/github/NorMasliza/GitHubProject/blob/main/DATASAINS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/StudentsPerformance_with_headers.csv')

# %%
data
# Out:
#      STUDENT ID  Student Age  Sex  Graduated high-school type  \
# 0      STUDENT1            2    2                           3
# 1      STUDENT2            2    2                           3
# 2      STUDENT3            2    2                           2
# 3      STUDENT4            1    1                           1
# 4      STUDENT5            2    2                           1
# ..          ...          ...  ...                         ...
# 140  STUDENT141            2    1                           2
# 141  STUDENT142            1    1                           2
# 142  STUDENT143            1    1                           1
# 143  STUDENT144            2    1                           2
# 144  STUDENT145            1    1                           1
#
#      Scholarship type  Additional work  Regular artistic or sports activity  \
# 0                   3                1                                    2
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 33 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   STUDENT ID                                                         145 non-null    object
#  1   Student Age                                                        145 non-null    int64
#  2   Sex                                                                145 non-null    int64
#  3   Graduated high-school type                                         145 non-null    int64
#  4   Scholarship type                                                   145 non-null    int64
#  5   Additional work                                                    145 non-null    int64
#  6   Regular artistic or sports activity                                145 non-null    int64
# ...

# %%
#STUDENT AGE

#min
min = data['Student Age'].min()

#max
max = data['Student Age'].max()

#mean
mean = data['Student Age'].mean()
rounded_mean = round(mean, 2)

#median
median = data['Student Age'].median()

#mode
mode = data['Student Age'].mode()

#standard deviation
std_dev = data['Student Age'].std()
rounded_std_dev = round(std_dev, 2)

print("min student age: ",min)
print("max student age: ",max)
print("mean student age: ",rounded_mean)
print("median student age: ",median)
print("mode student age: ",mode)
print("standard deviation of student age:  ", rounded_std_dev)
# Out:
# min student age:  1
# max student age:  3
# mean student age:  1.62
# median student age:  2.0
# mode student age:  0    2
# Name: Student Age, dtype: int64
# standard deviation of student age:   0.61

# %%
#weekly study hour

#min
min = data['Weekly study hours'].min()

#max
max = data['Weekly study hours'].max()

#mean
mean = data['Weekly study hours'].mean()
rounded_mean = round(mean, 2)

#median
median = data['Weekly study hours'].median()

#mode
mode= data['Weekly study hours'].mode()

#standard deviation
std_dev = data['Weekly study hours'].std()
rounded_std_dev = round(std_dev, 2)


print("min Weekly study hours: ",min)
print("max Weekly study hours: ",max)
print("mean Weekly study hours: ",rounded_mean)
print("median Weekly study hours: ",median)
print("mode Weekly study hours: ",mode)
print("standard deviation of Weekly study hours:  ", rounded_std_dev)
# Out:
# min Weekly study hours:  1
# max Weekly study hours:  5
# mean Weekly study hours:  2.2
# median Weekly study hours:  2.0
# mode Weekly study hours:  0    2
# Name: Weekly study hours, dtype: int64
# standard deviation of Weekly study hours:   0.92

# %%
#Cumulative grade point average in the last semester (/4.00)

#min
min = data['Cumulative grade point average in the last semester (/4.00)'].min()

#max
max = data['Cumulative grade point average in the last semester (/4.00)'].max()

#mean
mean = data['Cumulative grade point average in the last semester (/4.00)'].mean()
rounded_mean = round(mean, 2)

#median
median = data['Cumulative grade point average in the last semester (/4.00)'].median()

#mode
mode= data['Cumulative grade point average in the last semester (/4.00)'].mode()

#standard deviation
std_dev = data['Cumulative grade point average in the last semester (/4.00)'].std()
rounded_std_dev = round(std_dev, 2)


print("min Cumulative grade point average in the last semester (/4.00): ",min)
print("max Cumulative grade point average in the last semester (/4.00): ",max)
print("mean Cumulative grade point average in the last semester (/4.00): ",rounded_mean)
print("median Cumulative grade point average in the last semester (/4.00): ",median)
print("mode Cumulative grade point average in the last semester (/4.00): ",mode)
print("standard deviation of Cumulative grade point average in the last semester (/4.00):  ", rounded_std_dev)
# Out:
# min Cumulative grade point average in the last semester (/4.00):  1
# max Cumulative grade point average in the last semester (/4.00):  5
# mean Cumulative grade point average in the last semester (/4.00):  3.12
# median Cumulative grade point average in the last semester (/4.00):  3.0
# mode Cumulative grade point average in the last semester (/4.00):  0    4
# Name: Cumulative grade point average in the last semester (/4.00), dtype: int64
# standard deviation of Cumulative grade point average in the last semester (/4.00):   1.3

# %%
# Calculating the IQR
quartiles = data['Student Age'].quantile([0.25, 0.75])
iqr = quartiles[0.75] - quartiles[0.25]
print('Student Age',iqr)

quartiles = data['Weekly study hours'].quantile([0.25, 0.75])
iqr = quartiles[0.75] - quartiles[0.25]
print('Weekly study hours',iqr)

quartiles = data['Cumulative grade point average in the last semester (/4.00)'].quantile([0.25, 0.75])
iqr = quartiles[0.75] - quartiles[0.25]
print('Cumulative grade point average in the last semester (/4.00)',iqr)
# Out:
# Student Age 1.0
# Weekly study hours 1.0
# Cumulative grade point average in the last semester (/4.00) 2.0

# %%
corr_matrix = data.corr()
corr_matrix
# Out:
# <ipython-input-10-b20f780b4413>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()
#                                                     Student Age       Sex  \
# Student Age                                            1.000000  0.138233
# Sex                                                    0.138233  1.000000
# Graduated high-school type                             0.294426  0.126218
# Scholarship type                                      -0.316506 -0.206876
# Additional work                                       -0.181019  0.190476
# Regular artistic or sports activity                    0.138233  0.224138
# Do you have a partner                                  0.042572 -0.125471
# Total salary if available                              0.127853 -0.022154
# ...

# %%
print("The correlation value:", data['Weekly study hours'].corr(data['Expected Cumulative grade point average in the graduation (/4.00)']))
# Out:
# The correlation value: 0.06607054415804935

# %%
print("The correlation value:" ,data['Taking notes in classes'].corr(data['Preparation to midterm exams 2']))
# Out:
# The correlation value: 0.057902542752571895

# %%
print("The correlation value:" ,data['Cumulative grade point average in the last semester (/4.00)'].corr(data['Expected Cumulative grade point average in the graduation (/4.00)']))
# Out:
# The correlation value: 0.6578531617921811

# %%
import seaborn as sns
sns.set_style('whitegrid')
sns.lmplot(x='Weekly study hours',y='Expected Cumulative grade point average in the graduation (/4.00)',data=data,
           palette='coolwarm',height=4,aspect=3,fit_reg=True)

# %%
import seaborn as sns
sns.set_style('whitegrid')
sns.lmplot(x='Taking notes in classes',y='Preparation to midterm exams 2',data=data,
           palette='coolwarm',height=4,aspect=3,fit_reg=True)

# %%
import seaborn as sns
sns.set_style('whitegrid')
sns.lmplot(x='Cumulative grade point average in the last semester (/4.00)',y='Expected Cumulative grade point average in the graduation (/4.00)',data=data,
           palette='coolwarm',height=4,aspect=3,fit_reg=True)

# %%
import seaborn as sn
sn.heatmap(corr_matrix, annot=True)
plt.show()
